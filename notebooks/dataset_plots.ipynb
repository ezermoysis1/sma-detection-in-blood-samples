# %%
from plotting import filter_and_plot

# %%
filter_and_plot('RCM_cells_cleaned_paper', 'samples_dataset.csv')
# Out:
# All subdirectory names are in the csv file

# %%
filter_and_plot('RCM_cells_cleaned', 'samples_dataset.csv')
# Out:
# All subdirectory names are in the csv file

# %%
filter_and_plot('RCM_cells_cleaned_balanced', 'samples_dataset.csv')
# Out:
# All subdirectory names are in the csv file

# %%
filter_and_plot('edof_new_sma_2023', 'new_data1.csv')
# Out:
# Neither '250119-20' nor '250119-020' are in the csv file
# The following subdirectory names are not in the csv file:
# 250119-20
